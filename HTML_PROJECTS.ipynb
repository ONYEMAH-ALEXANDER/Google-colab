# %% [markdown]
# <a href="https://colab.research.google.com/github/ONYEMAH-ALEXANDER/Google-colab/blob/main/HTML_PROJECTS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import HTML

html_code = """
<!--My first Personal Bio Page Project-->
<!--Personal Bio Page
Intro, name, photo, hobbies, contact info
→ Use: <h1>, <p>, <img>, <a>-->

<!DOCTYPE html>
<html lang="en">
    <head>
        <title>Personal Bio Page</title>
        <meta charset="UTF-8">
        <meta name="viewport"  content="width=device-width, initial-scale=1.0">
        <meta name="keywords" content="Personal Bio Page">
        <meta name="description" content="A simple personal page">
        <meta name="Author" content="Alexander">
    </head>
    <body>
        <h1><strong>Welcome To Lexamitch Enterprises</strong></h1>
        <hr>
        <p>My name is <strong>ONYEMAH ALEXANDER</strong></p>
        <p>My Hobbies are Reading, Coding, Watching Movies And Likes Playing Games</p>
        <p>Check Out the Image Below:</p>
        <img src="LEX-ENTERPRISES.jpg" alt="Lexamicth Enterprises Logo" width="300" height="300">
        <p>Learning about <a href="https://www.w3schools.com/html/html_div.asp" target="_blank">HTML</a></p>
        <p>Kindly check My Details Below:</p>
        <p>My contact Info: <a href="tel:08029806097">&phone; 08029806097</a></p>
        <p>&copy; Lexamicth Enterprises 2025</p>
        <p>&reg; Lexamicth Enterprises</p>
    </body>
</html>
"""

HTML(html_code)
# Out:
# <!--My first Personal Bio Page Project-->
# <!--Personal Bio Page
# Intro, name, photo, hobbies, contact info
# → Use: <h1>, <p>, <img>, <a>-->
#
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>Personal Bio Page</title>
#         <meta charset="UTF-8">
#         <meta name="viewport"  content="width=device-width, initial-scale=1.0">
#         <meta name="keywords" content="Personal Bio Page">
#         <meta name="description" content="A simple personal page">
#         <meta name="Author" content="Alexander">
#     </head>
#     <body>
#         <h1><strong>Welcome To Lexamitch Enterprises</strong></h1>
#         <hr>
#         <p>My name is <strong>ONYEMAH ALEXANDER</strong></p>
#         <p>My Hobbies are Reading, Coding, Watching Movies And Likes Playing Games</p>
#         <p>Check Out the Image Below:</p>
#         <img src="LEX-ENTERPRISES.jpg" alt="Lexamicth Enterprises Logo" width="300" height="300">
# ...
